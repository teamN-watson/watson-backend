# %%
import pandas as pd

eng_games_over_20k_users = pd.read_csv('eng_games_over_20k_users.csv')

# %%
eng_games_over_20k_users
# Out:
#          appID                               name  \
# 0      1469160                     Wartune Reborn
# 1       320150          Deadlings: Rotten Edition
# 2      1026420                             WARSAW
# 3       485000                     Cthulhu Realms
# 4       825930                  Royal Battleships
# ...        ...                                ...
# 14773  3085700                       Pretty Agent
# 14774  2840460               Mission: Rift seeker
# 14775  2920570  Dale & Dawson Stationery Supplies
# 14776  2908950                      Tunnel Escape
# 14777  2274970          When The Devil Takes Hold
#
#                                      supported_languages  \
# 0                                            ['English']
# 1      ['English', 'Polish', 'French', 'Italian', 'Ge...
# 2      ['English', 'French', 'German', 'Polish', 'Rus...
# 3                                            ['English']
# 4                                            ['English']
# ...

# %%
eng_games_over_20k_users = eng_games_over_20k_users.drop(columns='estimated_owners')

# %%
eng_games_over_20k_users
# Out:
#          appID                               name  \
# 0      1469160                     Wartune Reborn
# 1       320150          Deadlings: Rotten Edition
# 2      1026420                             WARSAW
# 3       485000                     Cthulhu Realms
# 4       825930                  Royal Battleships
# ...        ...                                ...
# 14773  3085700                       Pretty Agent
# 14774  2840460               Mission: Rift seeker
# 14775  2920570  Dale & Dawson Stationery Supplies
# 14776  2908950                      Tunnel Escape
# 14777  2274970          When The Devil Takes Hold
#
#                                      supported_languages  \
# 0                                            ['English']
# 1      ['English', 'Polish', 'French', 'Italian', 'Ge...
# 2      ['English', 'French', 'German', 'Polish', 'Rus...
# 3                                            ['English']
# 4                                            ['English']
# ...

# %%
kor_eng_games = pd.read_csv('kor-eng_games.csv')

# %%
kor_eng_games
# Out:
#          appID                     name  \
# 0      1355720                 Henosis™
# 1      1178150    MazM: Jekyll and Hyde
# 2      1454010           Diary of Lucie
# 3      1158910          Dream Detective
# 4       897820  Reigns: Game of Thrones
# ...        ...                      ...
# 11697  3128520               Fit My Cat
# 11698  2022930                  WARCANA
# 11699  3098370        Blackjack Of Lust
# 11700  2661620            Love in Login
# 11701  2593970              Blocky Farm
#
#                                      supported_languages  \
# 0      ['English', 'French', 'Italian', 'German', 'Sp...
# 1      ['English', 'French', 'Italian', 'German', 'Sp...
# 2                                  ['English', 'Korean']
# 3      ['English', 'French', 'German', 'Spanish - Spa...
# 4      ['English', 'French', 'German', 'Spanish - Spa...
# ...                                                  ...
# 11697  ['English', 'Traditional Chinese', 'Japanese',...
# ...

# %%
edited_filtered_games_data = pd.concat([eng_games_over_20k_users,kor_eng_games])

# %%
edited_filtered_games_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 edited_filtered_games_data
#
# NameError: name 'edited_filtered_games_data' is not defined

# %%
edited_filtered_games_data.to_csv('edited_filtered_games_data.csv')
