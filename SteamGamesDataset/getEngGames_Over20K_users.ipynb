# %%
import pandas as pd

df = pd.read_csv('filtered_games_data.csv')

# %%
df
# Out:
#          appID                    name  \
# 0        20200        Galactic Bowling
# 1       655370            Train Bandit
# 2      1732930            Jolt Project
# 3      1355720                Henosis™
# 4      1139950   Two Weeks in Painland
# ...        ...                     ...
# 97405  3080940  Femdom Game World: Mom
# 97406  2593970             Blocky Farm
# 97407  3137150    Infiltrate & Extract
# 97408  3124670       Escape The Garage
# 97409  3054200              Lober Lobe
#
#                                      supported_languages  \
# 0                                            ['English']
# 1      ['English', 'French', 'Italian', 'German', 'Sp...
# 2                     ['English', 'Portuguese - Brazil']
# 3      ['English', 'French', 'Italian', 'German', 'Sp...
# 4                         ['English', 'Spanish - Spain']
# ...                                                  ...
# 97405                             ['English', 'Russian']
# ...

# %%
df = df[df['supported_languages'].str.contains('English') & ~df['supported_languages'].str.contains('Korean')]
df['min_owners'] = df['estimated_owners'].str.split(' - ').str[0].astype(int)
df = df[df['min_owners'] >= 20000]

# %%
df
# Out:
#          appID                    name  \
# 0        20200        Galactic Bowling
# 1       655370            Train Bandit
# 2      1732930            Jolt Project
# 4      1139950   Two Weeks in Painland
# 5      1469160          Wartune Reborn
# ...        ...                     ...
# 97403  3165130             SLIME ORDER
# 97405  3080940  Femdom Game World: Mom
# 97407  3137150    Infiltrate & Extract
# 97408  3124670       Escape The Garage
# 97409  3054200              Lober Lobe
#
#                                      supported_languages  \
# 0                                            ['English']
# 1      ['English', 'French', 'Italian', 'German', 'Sp...
# 2                     ['English', 'Portuguese - Brazil']
# 4                         ['English', 'Spanish - Spain']
# 5                                            ['English']
# ...                                                  ...
# 97403                            ['English', 'Japanese']
# ...

# %%
df['min_owners'] = df['estimated_owners'].str.split(' - ').str[0].astype(int)
df = df[df['min_owners'] >= 20000]
# Out:
# /var/folders/s4/pkzw9g910vn4ty0qqq4931qm0000gn/T/ipykernel_28674/1638117046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_owners'] = df['estimated_owners'].str.split(' - ').str[0].astype(int)

# %%
df = df.drop(columns=['min_owners'])

# %%
df
# Out:
#          appID                               name  \
# 5      1469160                     Wartune Reborn
# 9       320150          Deadlings: Rotten Edition
# 10     1026420                             WARSAW
# 11      485000                     Cthulhu Realms
# 13      825930                  Royal Battleships
# ...        ...                                ...
# 97321  3085700                       Pretty Agent
# 97334  2840460               Mission: Rift seeker
# 97350  2920570  Dale & Dawson Stationery Supplies
# 97357  2908950                      Tunnel Escape
# 97371  2274970          When The Devil Takes Hold
#
#                                      supported_languages  \
# 5                                            ['English']
# 9      ['English', 'Polish', 'French', 'Italian', 'Ge...
# 10     ['English', 'French', 'German', 'Polish', 'Rus...
# 11                                           ['English']
# 13                                           ['English']
# ...

# %%
# summary
# 영어 지원 but 한글 미지원 필터
# 게임 보유 유저 추산치 20K이상 필터
# 예상치 적은 이유는 'English'도 없는 게임들, 결측치 drop됨.
df.set_index('appID', inplace=True)
df.to_csv('eng_games_over_20k_users.csv')
